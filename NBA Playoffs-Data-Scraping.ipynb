# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir("/Users/edward/Desktop/Data Science/nba-playoff-prediction/data")

# %%
# !find . -name '.DS_Store' -type f -delete

# %%
stats_files = os.listdir()
stats_files
# Out:
# ['defense_shooting_stats',
#  'offense_shooting_stats',
#  'offense',
#  'advanced_stats',
#  'defense']

# %%
for stats_type in stats_files :

    os.chdir("/Users/edward/Desktop/Data Science/nba-playoff-prediction/data")
    os.chdir(f'{stats_type}/')
    
    globals()[stats_type] = pd.DataFrame()
        
    # !find . -name '.DS_Store' -type f -delete
    
    curr_files = os.listdir()
    sorted_files = sorted(curr_files)[::-1]
    for file in sorted_files:        
        globals()[stats_type] = pd.concat([globals()[stats_type], pd.read_html(file)[0]], axis=0)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Offense

# %%
# Drop League Average Stats
offense = offense[offense["Team"]!="League Average"]
offense.reset_index(drop=True, inplace=True)

# %%
print(offense.shape)
offense.head()
# Out:
# (1043, 25)
#     Rk                   Team   G     MP    FG   FGA    FG%    3P   3PA  \
# 0  1.0       Milwaukee Bucks*  73  241.0  43.3  90.9  0.476  13.8  38.9
# 1  2.0       Houston Rockets*  72  241.4  40.8  90.4  0.451  15.6  45.3
# 2  3.0      Dallas Mavericks*  75  242.3  41.7  90.3  0.461  15.1  41.3
# 3  4.0  Los Angeles Clippers*  72  241.4  41.6  89.2  0.466  12.4  33.5
# 4  5.0   New Orleans Pelicans  72  242.1  42.6  91.6  0.465  13.6  36.9
#
#      3P%  ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  0.355  ...  0.742   9.5  42.2  51.7  25.9  7.2  5.9  15.1  19.6  118.7
# 1  0.345  ...  0.791   9.8  34.5  44.3  21.6  8.7  5.2  14.7  21.8  117.8
# 2  0.367  ...  0.779  10.5  36.4  46.9  24.7  6.1  4.8  12.7  19.5  117.0
# 3  0.371  ...  0.791  10.7  37.0  47.7  23.7  7.1  4.7  14.6  22.1  116.3
# 4  0.370  ...  0.729  11.1  35.4  46.5  26.8  7.5  5.0  16.4  21.2  115.8
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Defense

# %%
# Drop League Average Stats
defense = defense[defense["Team"]!="League Average"]
defense.reset_index(drop=True, inplace=True)

# %%
print(defense.shape)
defense.head()
# Out:
# (1043, 25)
#     Rk                 Team   G     MP    FG   FGA    FG%    3P   3PA    3P%  \
# 0  1.0     Toronto Raptors*  72  241.4  37.8  88.3  0.428  13.1  38.9  0.337
# 1  2.0      Boston Celtics*  72  242.1  38.4  87.1  0.441  11.8  34.8  0.340
# 2  3.0      Indiana Pacers*  73  241.4  39.5  88.5  0.446  11.5  33.6  0.341
# 3  4.0  Los Angeles Lakers*  71  240.7  39.1  87.1  0.448  11.6  33.4  0.349
# 4  5.0       Orlando Magic*  73  240.7  40.4  86.9  0.465  12.2  33.6  0.364
#
#    ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  ...  0.769  10.9  35.1  46.1  25.6  7.2  5.5  16.8  20.4  106.5
# 1  ...  0.767  10.3  34.0  44.3  22.4  7.1  5.5  15.2  20.7  107.3
# 2  ...  0.788  10.4  34.9  45.2  23.1  6.9  4.6  14.7  18.8  107.5
# 3  ...  0.781   9.4  32.9  42.3  23.4  8.2  3.7  15.9  21.7  107.6
# 4  ...  0.771   9.0  35.8  44.9  24.7  7.0  4.6  14.6  19.5  108.3
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Advanced Stats

# %%
advanced_stats_columns = [columns[1] for columns in advanced_stats.columns]

# %%
advanced_stats_single_columns = advanced_stats.copy()
advanced_stats_single_columns.columns = advanced_stats_columns

# %%
# Drop League Average Stats
advanced_stats_single_columns = advanced_stats_single_columns[advanced_stats_single_columns["Team"]!="League Average"]
advanced_stats_single_columns.reset_index(drop=True, inplace=True)

# %%
# Drop null columns
columns_to_drop = advanced_stats_single_columns.columns[advanced_stats_single_columns.isna().sum() == 1043]
advanced_stats_single_columns.drop(columns_to_drop, axis=1, inplace=True)

# %%
advanced_stats_single_columns.head()
# Out:
#     Rk                   Team   Age     W     L  PW  PL    MOV   SOS   SRS  \
# 0  1.0       Milwaukee Bucks*  29.2  56.0  17.0  57  16  10.08 -0.67  9.41
# 1  2.0        Boston Celtics*  25.3  48.0  24.0  50  22   6.31 -0.47  5.83
# 2  3.0  Los Angeles Clippers*  27.4  49.0  23.0  50  22   6.44  0.21  6.66
# 3  4.0       Toronto Raptors*  26.6  53.0  19.0  50  22   6.24 -0.26  5.97
# 4  5.0    Los Angeles Lakers*  29.5  52.0  19.0  48  23   5.79  0.49  6.28
#
#    ...  TOV%  ORB%  FT/FGA   eFG%  TOV%  DRB%  FT/FGA             Arena  \
# 0  ...  12.9  20.7   0.201  0.489  12.0  81.6   0.178      Fiserv Forum
# 1  ...  12.2  23.9   0.207  0.509  13.5  77.4   0.215         TD Garden
# 2  ...  12.6  23.5   0.233  0.506  12.2  77.6   0.206    STAPLES Center
# 3  ...  13.1  21.3   0.210  0.502  14.6  76.7   0.202  Scotiabank Arena
# 4  ...  13.3  24.5   0.201  0.515  14.1  78.8   0.205    STAPLES Center
#
#    Attend.  Attend./G
# 0   549036    17711.0
# 1   610864    19090.0
# ...

# %% [markdown]
# # Export Data

# %%
current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
os.chdir(parent_directory)

current_directory = os.getcwd()
parent_directory = os.path.dirname(current_directory)
os.chdir(parent_directory)

# %%
os.getcwd()
# Out:
# '/Users/edward/Desktop/Data Science/nba-playoff-prediction'

# %%
offense.to_csv("offense.csv")

# %%
defense.to_csv("defense.csv")

# %%
advanced_stats_single_columns.to_csv("advanced_stats.csv")
